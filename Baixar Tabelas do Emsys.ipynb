# %%
#Invocar o EMSYS e logar a senha e usuário
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1

#Invoca tecla windows
pyautogui.press("win")
#procura e invoca o EMSYS
pyautogui.write("Go-global")
time.sleep(10)
pyautogui.press("enter")
time.sleep(10)
pyautogui.click(x=852, y=353)
time.sleep(60)#25 alterar posteriormente
#entra no EMSYS3
pyautogui.click(x=496, y=235,clicks=2)
time.sleep(18)
#Seleciona o banco de dados
pyautogui.click(x=651, y=365)
pyautogui.write("RedeSim")
pyautogui.press("enter")
time.sleep(5)
#Apaga qualquer usuario logado e entra no sistema
pyautogui.click(x=759, y=432)
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.click(x=759, y=432)
pyautogui.write("ayrisfilho")
pyautogui.click(x=691, y=496)
pyautogui.write("2022@log")
pyautogui.click(x=903, y=519)
time.sleep(8)
pyautogui.click(x=893, y=484)
time.sleep(12)
#expande os menus
pyautogui.click(x=13, y=197)
time.sleep(2)

#Acessa e baixa tabelas de Perdas AU033 - (leva Vendas food geral 12 a 15 minutos pra atualizar)
import pyautogui
import pyperclip
import time
import time

data= ("11/04/2023")
#data2=datetime.datetime.strptime(data, "%d/23/03/2023%m/%Y"27/01/2023)RedeSim


#print("{}/{}/{}".format(data2.day,data2.monayrisfilhoayrisfilho

display(data)

pyautogui.PAUSE = 1


#Abaixo irá acessar a tebela de quebras Au033
pyautogui.click(x=91, y=175)
pyperclip.copy("Au033")
pyautogui.hotkey("ctrl","v")
time.sleep(5)

pyautogui.click(x=151, y=310,clicks=2)
time.sleep(5)
#Movimentar o template
pyautogui.click(x=685, y=488)
time.sleep(5)
pyautogui.click(x=617, y=545)
pyautogui.click(x=780, y=484)
#Preenche a data inicial
pyautogui.click(x=646, y=346)
pyautogui.write("01/03/2023")
time.sleep(2)
#Preenche o dia anterior
pyautogui.click(x=645, y=371)
pyautogui.write(data)
time.sleep(2)

#Seleciona o tipo do produto

pyautogui.click(x=867, y=393)
pyautogui.click(x=714, y=470)
time.sleep(2)
pyautogui.click(x=632, y=432)
time.sleep(2)
#Seleciona todas as lojaslog@2022
pyautogui.click(x=416, y=293)
pyautogui.click(x=843, y=504)
time.sleep(10)
#seleciona o tipo de relatório
pyautogui.click(x=706, y=278,clicks=2)
time.sleep(3)
#localiza a posta que irá salvar
pyautogui.click(x=398, y=377)
time.sleep(10)#teste aqui o tempo certo para não travar a posta.
pyautogui.click(x=779, y=389,clicks=2)
pyautogui.click(x=593, y=503)
pyautogui.write("Users")
pyautogui.press("enter")
pyautogui.click(x=593, y=503)
pyautogui.write("ayres.filho")
pyautogui.press("enter")
pyautogui.click(x=593, y=503)
pyautogui.write("Desktop")
pyautogui.press("enter")
pyautogui.click(x=593, y=503)

#preenche o nome do relatório.
pyautogui.write("Quebras")
pyautogui.click(x=964, y=501)
time.sleep(900)#corrigir este cara para 900 home office

#Cica em ok e Fecha o template
pyautogui.click(x=673, y=405)
pyautogui.click(x=851, y=230)
time.sleep(5)
#apaga o relatório
pyautogui.click(x=152, y=173)
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("delete")
pyautogui.press("delete")
pyautogui.press("delete")
pyautogui.press("delete")
pyautogui.press("delete")

#Baixar Venda Geral dia anterior - (leva entre 8 a 12 minutos pra atualizar)

import pyautogui
import pyperclip
import time

time.sleep(10)

pyautogui.PAUSE = 1
#Abaixo irá acessar a tebela de vendas Fs005
pyautogui.click(x=91, y=175)
pyperclip.copy("Fs005")
pyautogui.hotkey("ctrl","v")
time.sleep(5)
#Seleciona tabela de vendas
pyautogui.click(x=222, y=364,clicks=2)
time.sleep(5)
#Movimentar o template
pyautogui.click(x=685, y=488)
time.sleep(5)
pyautogui.click(x=617, y=545)
pyautogui.click(x=780, y=484)
#Preenche a data inicial
pyautogui.click(x=648, y=401)
pyautogui.write(data)
time.sleep(2)
#Preenche o dia anterior
pyautogui.click(x=685, y=419)
pyautogui.write(data)
time.sleep(2)
pyautogui.click(x=647, y=455)
#Preenche os Grupos desejados
pyautogui.click(x=415, y=291)
time.sleep(3)
#Tira os grupos combustiveis e vinicolas
pyautogui.click(x=551, y=502)
pyautogui.write("COMBUSTIVEIS".upper())
time.sleep(2)
pyautogui.click(x=442, y=270)
pyautogui.click(x=441, y=290)
time.sleep(2)
pyautogui.click(x=607, y=501)
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
time.sleep(3)
#tira grupo vinicolas
pyautogui.click(x=551, y=502)
pyautogui.write("VINICOLA".upper())
time.sleep(2)
pyautogui.click(x=442, y=270)
time.sleep(1)
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
time.sleep(3)
pyautogui.click(x=843, y=502)
#Seleciona todas as lojas
pyautogui.click(x=416, y=293)
pyautogui.click(x=843, y=504)
time.sleep(10)
#seleciona o tipo de relatório
pyautogui.click(x=706, y=278,clicks=2)
time.sleep(3)
#preenche o nome do relatório.
pyautogui.write("Venda geral")
pyautogui.click(x=964, y=501)
time.sleep(480)#arrumar este cara para 480 home office
#Cica em ok e Fecha o template
pyautogui.click(x=673, y=405)
time.sleep(5)

#Baixar Vendas FOOD dia anterior - (leva 3 minutos pra atualizar)
import pyautogui
import pyperclip
import time

time.sleep(10)
pyautogui.PAUSE = 1

pyautogui.click(x=784, y=479)
time.sleep(5)
#Preenche a data inicial
pyautogui.click(x=648, y=401)
pyautogui.write(data)
time.sleep(2)
#Preenche o dia anterior
pyautogui.click(x=685, y=419)
pyautogui.write(data)
time.sleep(2)
pyautogui.click(x=647, y=42055)
pyautogui.click(x=627, y=454)
#Preenche os Grupos desejados
time.sleep(3)
#Seleciona os grupo FOOD
pyautogui.click(x=551, y=502)
pyautogui.write("FOOD SERVICE".upper())
time.sleep(2)
pyautogui.click(x=442, y=270)
pyautogui.click(x=441, y=290)
time.sleep(2)
pyautogui.click(x=607, y=501)
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
time.sleep(3)
pyautogui.click(x=843, y=502)
#Seleciona todas as lojas
pyautogui.click(x=416, y=293)
pyautogui.click(x=843, y=504)
time.sleep(10)
#seleciona o tipo de relatório
pyautogui.click(x=706, y=278,clicks=2)
time.sleep(3)
#preenche o nome do relatório.
pyautogui.write("Vendas food")
pyautogui.click(x=964, y=501)
time.sleep(60) #arrumar este cara para 180 segundos home office
#Cica em ok e Fecha o template
pyautogui.click(x=673, y=405)
pyautogui.click(x=851, y=230)
time.sleep(5)
#apaga o relatório
pyautogui.click(x=152, y=173)
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")

#baixar tabela CUPON CANCELADO AU006 - (leva entre 3 minutos para atualizar)
import pyautogui
import pyperclip
import time

time.sleep(10)
pyautogui.PAUSE = 1

#Abaixo irá acessar a tebela de quebras Au033
pyautogui.click(x=91, y=175)
pyperclip.copy("Au006")
pyautogui.hotkey("ctrl","v")
time.sleep(5)

pyautogui.click(x=151, y=310,clicks=2)
time.sleep(5)
#Movimentar o template
pyautogui.click(x=685, y=488)
time.sleep(5)
pyautogui.click(x=617, y=545)
pyautogui.click(x=780, y=484)
#Preenche a data inicial
pyautogui.click(x=646, y=346)
pyautogui.write(data)
time.sleep(2)
#Preenche o dia anterior
pyautogui.click(x=645, y=371)
pyautogui.write(data)
pyautogui.click(x=642, y=433)
time.sleep(2)
#Seleciona todas as lojas
pyautogui.click(x=416, y=293)
pyautogui.click(x=843, y=504)
time.sleep(10)
#seleciona o tipo de relatório
pyautogui.click(x=669, y=305,clicks=2)
time.sleep(3)
#preenche o nome do relatório.
pyautogui.write("Cupon cancelado")
pyautogui.click(x=964, y=501)
time.sleep(60)#arrumar para 120 home ooffice
#Cica em ok e Fecha o template
pyautogui.click(x=673, y=405)
pyautogui.click(x=851, y=230)
time.sleep(5)
#apaga o relatório
pyautogui.click(x=152, y=173)
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")
pyautogui.press("backspace")

#baixar tabela SALDO DE ESTOQUE AU040 - (leva entre 3 minutos para atualizar)
import pyautogui
import pyperclip
import time

time.sleep(10)
pyautogui.PAUSE = 1

#Abaixo irá acessar a tebela de quebras Au033
pyautogui.click(x=91, y=175)
pyperclip.copy("Au040")
pyautogui.hotkey("ctrl","v")
time.sleep(5)
pyautogui.click(x=151, y=310,clicks=2)
time.sleep(5)
#Movimentar o template
pyautogui.click(x=685, y=488)
time.sleep(5)
pyautogui.click(x=617, y=545)
pyautogui.click(x=780, y=484)
#Seleciona os parametros
pyautogui.click(x=630, y=448)
time.sleep(2)
#Seleciona todas as lojas
pyautogui.click(x=416, y=293)
pyautogui.click(x=843, y=50)
pyautogui.click(x=846, y=504)
time.sleep(6)
#seleciona o tipo de relatório
pyautogui.click(x=597, y=278,clicks=2)
time.sleep(6)
#preenche o nome do relatório
pyautogui.click(x=574, y=499)
pyautogui.write("saldo de estoque")
pyautogui.click(x=963, y=498)
# Out:
# '10/04/2023'
