# %% [markdown]
# ESTOQUE TOTAL = GERAR EM CSV

# %%
import pandas as pd

dados = pd.read_csv('C:/Users/ayres.filho/Downloads/Niveis_estoque_relatorio_08112022_105719.csv',sep=';',#sep='\t'
                  lineterminator='\r',
                  error_bad_lines=False)
# Out:
# C:\Users\ayres.filho\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dados.head()

# %%
dados['nom_fantasia'].value_counts() # conta os dados desejados

# %%
import pandas as pd
import openpyxl

#df = pd.read_csv('C:/Users/ayres.filho/Downloads/Niveis_estoque_relatorio_04102022_084543.csv')
df = pd.read_excel("C:/Users/ayres.filho/Desktop/Auditoria/Estoque REDE.xlsx")

# %%
df.head()
# Out:
#   Analisado            EAN  Código                               Descrição  \
# 0         N  8711500483454   17793  134814 LAMPADA AUTOMOT AUX SINALIZACAO
# 1         N  8711500483454   17793  134814 LAMPADA AUTOMOT AUX SINALIZACAO
# 2         N  8711500483454   17793  134814 LAMPADA AUTOMOT AUX SINALIZACAO
# 3         N  8711500483454   17793  134814 LAMPADA AUTOMOT AUX SINALIZACAO
# 4         N  8711500483454   17793  134814 LAMPADA AUTOMOT AUX SINALIZACAO
#
#    Código filial             Filial ABC Sin.  Qtd. estoque atual  \
# 0             72   ITAJAI DALCOQUIO   C   EX                 8.0
# 1             73  ITAJAI SANTA ROSA   D   NR                 0.0
# 2             80  LAGUNA CAMARAO SC   D   NR                 0.0
# 3            112      DOIS LAJEADOS   D   NR                 0.0
# 4            141     IMBITUBA FERJU   D   NR                 0.0
#
#    Val. estoque atual  ...  Lote reposição  Num. pedido  Data última venda  \
# ...

# %%
import pandas as pd

dados = pd.read_csv('C:/Users/ayres.filho/Downloads/Niveis_estoque_relatorio_08112022_105719.csv',sep=';',#sep='\t'
                  lineterminator='\r',
                  error_bad_lines=False)
dados.to_excel("Resultado estoque.xlsx", index=False)
# Out:
# C:\Users\ayres.filho\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
